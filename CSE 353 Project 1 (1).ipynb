# %%
# !pip install wordcloud

# %% [markdown]
# Problem:
#
# Terrorism poses a persistent threat, affecting various regions worldwide. However, the vast, unstructured data on global terrorism incidents lacks sufficient analysis to draw meaningful insights. Without a clear understanding of historical patterns, attack types, affected regions, and common targets, stakeholders find it challenging to develop effective counter-terrorism strategies. This gap in analysis limits the ability to make informed policy and security decisions.

# %% [markdown]
# Solution:
#
# This project, "Exploratory Data Analysis of Global Terrorism Patterns and Trends," tackles this problem by conducting a thorough analysis of historical terrorism data. Using EDA techniques, we can:
#
# Identify patterns and trends in terrorist activities over time.
# Visualize hotspots and regions most affected by terrorism.
# Analyze attack types, target groups, and frequently used weapons.
# Examine correlations between attack types, geographical locations, and casualties.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
data = pd.read_csv('globalterrorismdb_0718dist.csv',encoding = 'ISO-8859-1',low_memory =False)
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
data.head(10)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
# 5  197001010002   1970       1     1        NaN         0        NaN      217
# 6  197001020001   1970       1     2        NaN         0        NaN      218
# 7  197001020002   1970       1     2        NaN         0        NaN      217
# 8  197001020003   1970       1     2        NaN         0        NaN      217
# 9  197001030001   1970       1     3        NaN         0        NaN      217
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# ...

# %%
data.shape
# Out:
# (181691, 135)

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
data.rename(columns= {'iyear':'Year','imonth':'Month','country_txt':'Country',
                   'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target1',
                   'nkill':'Killed','nwound':'wounded','summary':'Summary','gname':'Group',
                   'targetype1_txt':'Target_type','weaptye1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
data.head()
# Out:
#         eventid  Year  Month  iday approxdate  extended resolution  country  \
# 0  197000000001  1970      7     2        NaN         0        NaN       58
# 1  197000000002  1970      0     0        NaN         0        NaN      130
# 2  197001000001  1970      1     0        NaN         0        NaN      160
# 3  197001000002  1970      1     0        NaN         0        NaN       78
# 4  197001000003  1970      1     0        NaN         0        NaN      101
#
#               Country  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %%
print(data.columns)
# Out:
# Index(['eventid', 'Year', 'Month', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'Country', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
column_names = list(data.columns)
print(column_names)
# Out:
# ['eventid', 'Year', 'Month', 'iday', 'approxdate', 'extended', 'resolution', 'country', 'Country', 'region', 'Region', 'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity', 'location', 'Summary', 'crit1', 'crit2', 'crit3', 'doubtterr', 'alternative', 'alternative_txt', 'multiple', 'success', 'suicide', 'attacktype1', 'AttackType', 'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt', 'corp1', 'Target1', 'natlty1', 'natlty1_txt', 'targtype2', 'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3', 'natlty3_txt', 'Group', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3', 'Motive', 'guncertain1', 'guncertain2', 'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'claimmode2_txt', '
# ...

# %%
data['Motive']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 181686    NaN
# 181687    NaN
# 181688    NaN
# 181689    NaN
# 181690    NaN
# Name: Motive, Length: 181691, dtype: object

# %%
df=data

# %%
attacks_per_year = df['Year'].value_counts().sort_index()

# %%
plt.figure(figsize=(10, 6)) 
colors = ['skyblue', 'salmon', 'lightgreen', 'gold', 'lightcoral', 'lightskyblue', 'plum', 'lightyellow', 'lightpink', 'lightgreen']
attacks_per_year.plot(kind='bar', color=colors)
plt.title('Number of Terrorist Attacks Each Year')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.grid(axis='y')
plt.show()

# %%
numerical_columns = ['Year', 'Month', 'iday']  

numerical_summary = df[numerical_columns].describe()
print(numerical_summary)
# Out:
#                 Year          Month           iday
# count  181691.000000  181691.000000  181691.000000
# mean     2002.638997       6.467277      15.505644
# std        13.259430       3.388303       8.814045
# min      1970.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       8.000000
# 50%      2009.000000       6.000000      15.000000
# 75%      2014.000000       9.000000      23.000000
# max      2017.000000      12.000000      31.000000

# %%
attack_type_counts = df['AttackType'].value_counts()

plt.figure(figsize=(10, 6))
attack_type_counts.plot(kind='bar', color='red')
plt.title('Distribution of Attack Types')
plt.xlabel('Attack Type')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
print("Attack Types and Frequencies:")
print(attack_type_counts)
# Out:
# Attack Types and Frequencies:
# AttackType
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: count, dtype: int64

# %%
country_attacks = data['Country'].value_counts()

plt.figure(figsize=(11, 6))
country_attacks.head(15).plot(kind='bar', color='blue')  
plt.title('Number of Terrorist Attacks by Country (Top 15)')
plt.xlabel('Country')
plt.ylabel('Number of Attacks')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
print("Country-wise Attacks (Top 15):")
print(country_attacks.head(15))
# Out:
# Country-wise Attacks (Top 15):
# Country
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Name: count, dtype: int64

# %%
countries_involved = df['Country'].dropna()

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(countries_involved))

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Word Cloud for Countries Involved in Terrorist Incidents')
plt.axis('off')
plt.tight_layout()
plt.show()

# %%
target_type_counts = df['targtype1_txt'].value_counts()

plt.figure(figsize=(12, 8))
target_type_counts.plot(kind='bar', color='violet')
plt.title('Distribution of Target Types in Terrorist Attacks')
plt.xlabel('Target Type')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
print("Target Types and Frequencies:")
print(target_type_counts)
# Out:
# Target Types and Frequencies:
# targtype1_txt
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: count, dtype: int64

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

target_type = df['targtype1_txt'].dropna()

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(target_type))

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Word Cloud for types of targets Involved in Terrorist Incidents')
plt.axis('off')
plt.tight_layout()
plt.show()

# %%
yearly_casualties = df.groupby('Year')[['Killed', 'wounded']].sum()

plt.figure(figsize=(12, 6))
bar_width = 0.35
index = np.arange(len(yearly_casualties))

plt.bar(index, yearly_casualties['Killed'], bar_width, label='Number Killed', color='skyblue')
plt.bar(index + bar_width, yearly_casualties['wounded'], bar_width, label='Number Wounded', color='salmon')

plt.xlabel('Year')
plt.ylabel('Number of People')
plt.title('Comparison of People Wounded and Killed Each Year')
plt.xticks(index + bar_width / 2, yearly_casualties.index, rotation=90)
plt.legend()
plt.tight_layout()
plt.show()

# %%
country_casualties = df.groupby('country')[['Killed', 'wounded']].sum()

country_casualties['total_casualties'] = country_casualties['Killed'] + country_casualties['wounded']
country_casualties = country_casualties.sort_values(by='total_casualties', ascending=False).head(15)

plt.figure(figsize=(12, 8))
country_casualties[['Killed', 'wounded']].plot(kind='bar', stacked=True, color=['red', 'orange'])
plt.title('Comparison of People Wounded and Killed in Top 15 Affected Countries')
plt.xlabel('Country')
plt.ylabel('Number of People')
plt.xticks(rotation=45)
plt.legend(['Number Killed', 'Number Wounded'])
plt.tight_layout()
plt.show()

# %%
city_wounded = df.groupby('city')['wounded'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
city_wounded.head(15).plot(kind='bar', color='brown')
plt.title('Number of People Wounded in Top Affected Cities')
plt.xlabel('City')
plt.ylabel('Number of People Wounded')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
print("Top Cities by Number of People Wounded:")
print(city_wounded.head(15))
# Out:
# Top Cities by Number of People Wounded:
# city
# Baghdad          56725.0
# New York City    16781.0
# Unknown          12803.0
# Kabul             5973.0
# Mosul             5787.0
# Karachi           5688.0
# Tokyo             5542.0
# Beirut            5341.0
# Nairobi           5024.0
# Kirkuk            5008.0
# Mogadishu         4955.0
# Colombo           4520.0
# Peshawar          3938.0
# Quetta            3842.0
# Aleppo            3623.0
# Name: wounded, dtype: float64

# %%
group_destruction = df.groupby('Group')[['Killed', 'property']].sum()
group_destruction = group_destruction.sort_values(by='Killed', ascending=False)

print("Top Terrorist Groups by Destruction:")
print(group_destruction.head(10))
# Out:
# Top Terrorist Groups by Destruction:
#                                                     Killed  property
# Group
# Unknown                                           112367.0    -64886
# Islamic State of Iraq and the Levant (ISIL)        38923.0     -9787
# Taliban                                            29410.0     -8082
# Boko Haram                                         20328.0     -2069
# Shining Path (SL)                                  11601.0      3433
# Liberation Tigers of Tamil Eelam (LTTE)            10989.0      -543
# Al-Shabaab                                          9330.0     -6751
# Farabundo Marti National Liberation Front (FMLN)    8065.0      3190
# Nicaraguan Democratic Force (FDN)                   6662.0       881
# Tehrik-i-Taliban Pakistan (TTP)                     6042.0      -851

# %%
group_attacks = df['Group'].value_counts().head(10)

plt.figure(figsize=(12, 6))
group_attacks.plot(kind='bar', color='Green')
plt.title('Number of Attacks per Top 10 Terrorist Groups')
plt.xlabel('Terrorist Group')
plt.ylabel('Number of Attacks')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
target_type_stats = df.groupby('targtype1_txt')[['Killed', 'wounded']].sum()

plt.figure(figsize=(12, 8))
target_type_stats.plot(kind='bar', color=['Red', 'yellow'])
plt.title('People Killed vs Wounded in Each Target Type Attack')
plt.xlabel('Target Type')
plt.ylabel('Number of People')
plt.xticks(rotation=90)
plt.legend(['Number Killed', 'Number Wounded'])
plt.tight_layout()
plt.show()

# %%
attack_type_killed = df.groupby('AttackType')['Killed'].sum().sort_values(ascending=False)

plt.figure(figsize=(11, 6))
attack_type_killed.plot(kind='bar', color='red')
plt.title('Number of People Killed in Each Attack Type')
plt.xlabel('Attack Type')
plt.ylabel('Number of People Killed')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
attacktype_killed=df[["AttackType","Killed"]].groupby("AttackType").sum().sort_values(by="Killed",ascending=False)
attacktype_killed
# Out:
#                                        Killed
# AttackType
# Armed Assault                        160297.0
# Bombing/Explosion                    157321.0
# Unknown                               32381.0
# Assassination                         24920.0
# Hostage Taking (Kidnapping)           24231.0
# Hostage Taking (Barricade Incident)    4478.0
# Hijacking                              3718.0
# Facility/Infrastructure Attack         3642.0
# Unarmed Assault                         880.0

# %%
total_people_killed = df['Killed'].sum()
total_people_wounded = df['wounded'].sum()

print(f"Total number of people killed: {total_people_killed}")
print(f"Total number of people wounded: {total_people_wounded}")
# Out:
# Total number of people killed: 411868.0
# Total number of people wounded: 523869.0

# %%
top_target_types = df['targtype1_txt'].value_counts().head(5)
print("\nTop 5 Most Common Target Types:")
print(top_target_types)
# Out:
# Top 5 Most Common Target Types:
# targtype1_txt
# Private Citizens & Property    43511
# Military                       27984
# Police                         24506
# Government (General)           21283
# Business                       20669
# Name: count, dtype: int64

# %%
top_attack_types = df['AttackType'].value_counts().head(5)
print("\nTop 5 Most Common Attack Types:")
print(top_attack_types)
# Out:
# Top 5 Most Common Attack Types:
# AttackType
# Bombing/Explosion                 88255
# Armed Assault                     42669
# Assassination                     19312
# Hostage Taking (Kidnapping)       11158
# Facility/Infrastructure Attack    10356
# Name: count, dtype: int64

# %%
incidents_per_year = df['Year'].value_counts().sort_index()
print("\nNumber of Incidents per Year:")
print(incidents_per_year)
# Out:
# Number of Incidents per Year:
# Year
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 1983     2870
# 1984     3495
# 1985     2915
# 1986     2860
# 1987     3183
# 1988     3721
# 1989     4324
# 1990     3887
# 1991     4683
# 1992     5071
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3197
# 1998      934
# 1999     1395
# 2000     1814
# 2001     1906
# 2002     1333
# 2003     1278
# 2004     1166
# 2005     2017
# 2006     2758
# 2007     3242
# 2008     4805
# 2009     4721
# 2010     4826
# 2011     5076
# 2012     8522
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900
# Name: count, dtype: int64

# %%
top_countries = df['Country'].value_counts().head(5)
print("\nTop 5 Affected Countries:")
print(top_countries)
# Out:
# Top 5 Affected Countries:
# Country
# Iraq           24636
# Pakistan       14368
# Afghanistan    12731
# India          11960
# Colombia        8306
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
attacks_over_time = df['Year'].value_counts().sort_index()
plt.plot(attacks_over_time.index, attacks_over_time.values, marker='o', linestyle='-')
plt.title('Trend of Terrorist Attacks Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.grid(True)
plt.show()

# %% [markdown]
# ## UNIVARIATE ANALYSIS

# %% [markdown]
# ### 1.Attack Types Distribution

# %%
plt.figure(figsize=(10,4))
sns.countplot(data=data, x='AttackType', order=data['AttackType'].value_counts().index)
plt.title('Distribution of Attack Types')
plt.xticks(rotation=45)
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# ### 2. Target Types Distribution

# %%
plt.figure(figsize=(15,4))
sns.countplot(data=data, x='targtype1_txt', order=data['targtype1_txt'].value_counts().index)
plt.title('Distribution of Target Types')
plt.xticks(rotation=45)
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# ### 3. Weapons Used Distribution

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='weaptype1_txt', order=data['weaptype1_txt'].value_counts().index)
plt.title('Distribution of Weapons Used')
plt.xticks(rotation=45)
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# ### 4. Casualties Distribution

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data['Killed'], bins=30, kde=True)
plt.title('Distribution of Casualties (Killed)')
plt.xlabel('Number of Killed')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 5. Ransom Amount Distribution

# %%
plt.figure(figsize=(12, 3))
sns.histplot(data['ransomamt'], bins=30, kde=True)
plt.title('Distribution of Ransom Amounts')
plt.xlabel('Ransom Amount')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 6. Geographic Distribution of Attacks

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='country', order=data['country'].value_counts().index)
plt.title('Distribution of Attacks by Country')
plt.xticks(rotation=90)
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# ### 7. Success Rate of Attacks

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='success')
plt.title('Success Rate of Attacks')
plt.xticks(ticks=[0, 1], labels=['Failed', 'Successful'])
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# ### 8. Yearly Trends in Attacks

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='Year')
plt.title('Number of Attacks Per Year')
plt.xticks(rotation=45)
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# ### 9. Hostage Outcomes

# %%
plt.figure(figsize=(4, 2))
sns.countplot(data=data, x='hostkidoutcome_txt', order=data['hostkidoutcome_txt'].value_counts().index)
plt.title('Distribution of Hostage Outcomes')
plt.xticks(rotation=45)
plt.ylabel('Number of Hostage Situations')
plt.show()

# %% [markdown]
# ## Bivariate analysis

# %% [markdown]
# ### 1. Attack Type vs. Casualties

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='AttackType', y='Killed')
plt.title('Casualties by Attack Type')
plt.xticks(rotation=45)
plt.ylabel('Number of Killed')
plt.show()

# %% [markdown]
# ### 2. Ransom Amount vs. Hostage Outcome

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='hostkidoutcome_txt', y='ransomamt')
plt.title('Ransom Amounts by Hostage Outcome')
plt.xticks(rotation=45)
plt.ylabel('Ransom Amount')
plt.show()

# %% [markdown]
# ### 3. Year vs. Attack Type

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='Year', hue='AttackType')
plt.title('Attack Types Over the Years')
plt.xticks(rotation=45)
plt.ylabel('Number of Attacks')
plt.legend(title='Attack Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# ### 4. Attack Type vs. Target Type

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='AttackType', hue='targtype1_txt')
plt.title('Target Types by Attack Type')
plt.xticks(rotation=45)
plt.ylabel('Number of Attacks')
plt.legend(title='Target Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# ### 5. Casualties vs. Weapons Used

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='weaptype1_txt', y='Killed')
plt.title('Casualties by Weapon Type')
plt.xticks(rotation=45)
plt.ylabel('Number of Killed')
plt.show()

# %% [markdown]
# ### 6. Success Rate vs. Attack Type

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='AttackType', hue='success')
plt.title('Success Rate by Attack Type')
plt.xticks(rotation=45)
plt.ylabel('Number of Attacks')
plt.legend(title='Success', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# ### 7. Yearly Trends in Casualties

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=data.groupby('Year')['Killed'].sum().reset_index(), x='Year', y='Killed')
plt.title('Yearly Casualties from Terrorist Attacks')
plt.xlabel('Year')
plt.ylabel('Total Casualties')
plt.show()

# %% [markdown]
# ### 8. Country vs. Attack Type

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='country', hue='AttackType', order=data['country'].value_counts().index[:10])
plt.title('Top 10 Countries by Attack Type')
plt.xticks(rotation=90)
plt.ylabel('Number of Attacks')
plt.legend(title='Attack Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# ### 9. Casualties vs. Hostage Outcomes

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='hostkidoutcome_txt', y='Killed')
plt.title('Casualties by Hostage Outcome')
plt.xticks(rotation=45)
plt.ylabel('Number of Killed')
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
sns. pairplot(df[['Killed', 'wounded', 'AttackType' ]], hue='AttackType', diag_kind='kde', height=2.5)
plt. suptitle('Pair Plot of Attack Type vs Casualties (Killed/Injured)', y=1.02)
plt. show()

# %%
casualty_by_region = df.groupby('Region' ).agg({'Killed': 'sum', 'wounded': 'sum'}) .reset_index()
plt.figure(figsize=(12,6))
plt. bar(casualty_by_region['Region'], casualty_by_region['Killed'], label='Killed', color='pink')
plt. bar(casualty_by_region['Region'], casualty_by_region['wounded' ], bottom=casualty_by_region['Killed'], label='Injured',color='blue')
plt.title('Casualties (Killed/Injured) by Region')
plt.xticks (rotation=90)
plt.ylabel('Total Casualties')
plt. legend()
plt.show()

# %% [markdown]
# # . Temporal Analysis

# %%
df_monthly = df.dropna(subset=['Year', 'Month'])
monthly_trend = df_monthly.groupby(['Year', 'Month']).size().unstack().fillna(0)
plt.figure(figsize=(14, 7))
sns.heatmap(monthly_trend, cbar_kws={'label': 'Number of Attacks'}, cmap='Spectral', linewidths=0.5)
plt.title('Monthly Trend in Terrorism Attacks (Heatmap)', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Year', fontsize=12)
plt.show()

# %%
region_year_data = df.pivot_table(index='region', columns='Year', aggfunc='size', fill_value=0)
plt.figure(figsize=(12,6))
sns. heatmap(region_year_data,cmap='plasma', linewidths=0.5)
plt. title('Terrorism Incidents Across Regions and Years')
plt.xlabel('Year')
plt.ylabel('Region')
plt.show()
